# %%
# 导入相关的包
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# 读取并展示图片
file_path = 'D:/post-graduate-study/暑期2021/深度学习/实验三/实验三数据集/车辆分类数据集/bus/bus002.jpg'
file = Path(file_path)
img = Image.open(file)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# 对图片进行变形
img = img.resize((200,100), Image.ANTIALIAS)
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x100 at 0x288AEB6A160>

# %%
# 将图片转成numpy矩阵形式
img = np.array(img)
print(img.shape)
# Out:
# (100, 200, 3)

# %%
# 归一化
img = img / 255
img
# Out:
# array([[[0.6       , 0.6745098 , 0.73333333],
#         [0.6       , 0.6745098 , 0.73333333],
#         [0.6       , 0.6745098 , 0.73333333],
#         ...,
#         [0.27843137, 0.36470588, 0.5254902 ],
#         [0.28235294, 0.37254902, 0.5254902 ],
#         [0.26666667, 0.35686275, 0.50980392]],
#
#        [[0.6       , 0.67843137, 0.73333333],
#         [0.6       , 0.67843137, 0.7372549 ],
#         [0.60392157, 0.68235294, 0.7372549 ],
#         ...,
#         [0.28235294, 0.35686275, 0.50980392],
#         [0.27058824, 0.34509804, 0.49411765],
#         [0.27058824, 0.34117647, 0.49019608]],
#
#        [[0.6       , 0.69019608, 0.74117647],
#         [0.60392157, 0.69019608, 0.74509804],
#         [0.60392157, 0.69019608, 0.74509804],
#         ...,
#         [0.29019608, 0.36470588, 0.50980392],
#         [0.24705882, 0.3254902 , 0.4627451 ],
#         [0.23529412, 0.30980392, 0.44705882]],
#
#        ...,
#
#        [[0.70588235, 0.65098039, 0.58823529],
# ...
